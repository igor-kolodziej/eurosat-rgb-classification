# %% [markdown]
# # 02 Preprocessing Comparison
#
# Thin report notebook for the saved preprocessing comparison artifacts.

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, Markdown, display

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'outputs').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

PREPROC_METRICS = PROJECT_ROOT / 'outputs' / 'metrics' / 'preprocessing'
PREPROC_FIGURES = PROJECT_ROOT / 'outputs' / 'figures' / 'preprocessing'

# %%
display(Markdown((PREPROC_METRICS / 'preprocessing_interpretation.md').read_text()))
display(pd.read_csv(PREPROC_METRICS / 'variant_summary.csv'))
display(pd.read_csv(PREPROC_METRICS / 'comparison_subset.csv').head())

# %%
for filename in [
    'variant_side_by_side.png',
    'variant_luminance_histograms.png',
]:
    display(Markdown(f'## {filename}'))
    display(Image(filename=PREPROC_FIGURES / filename))
